# %%
from torchvision.datasets.folder import pil_loader
import matplotlib.pyplot as plt
import numpy as np

# %%
path = "/home/mikhail/research/lie-pose-net/data/7scenes/chess/seq-01/frame-000000.color.png"

# %%
image = pil_loader(path)

# %%
plt.imshow(np.array(image))

# %%
image
# Out:
# <PIL.Image.Image image mode=RGB size=640x480 at 0x7F93A663EB70>
